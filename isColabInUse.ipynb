# %%
def isColabInUse(verbose=1):
  import sys
  IN_COLAB = 'google.colab' in sys.modules
  if (verbose == 1):
    if (IN_COLAB == 1):
      print('Running on CoLab')
    else:
      print('NOT running on CoLab')

  return IN_COLAB

# %%
## testing code

isColabInUse()
# Out:
# Running on CoLab
# True
